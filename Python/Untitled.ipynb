# %%
import readPyControl as pc
import pprint

pp = pprint.PrettyPrinter(width=410, compact=True)


fPath = '/media/jamesrowland/DATA/RawData/Behaviour/2018/GTRS2.4a_area01-2018-02-26-202403_encoder.pca'
x = pc.load_analog_data(fPath)


pp.pprint(x[0:100,:])

x.shape
# Out:
# array([[   0,    0],
#        [  50,    0],
#        [ 100,  -20],
#        [ 150,  -20],
#        [ 200,    0],
#        [ 250,    0],
#        [ 300,  -20],
#        [ 350,    0],
#        [ 400,    0],
#        [ 450,    0],
#        [ 500,    0],
#        [ 550,    0],
#        [ 600,  -20],
#        [ 650,    0],
#        [ 700,    0],
#        [ 750,    0],
#        [ 800,  -20],
#        [ 850,    0],
#        [ 900,    0],
#        [ 950,    0],
#        [1000,    0],
#        [1050,    0],
#        [1100,    0],
#        [1150,    0],
#        [1200,    0],
#        [1250,    0],
#        [1300,    0],
#        [1350,    0],
#        [1400,    0],
#        [1450,    0],
#        [1500,    0],
#        [1550,    0],
#        [1600,    0],
#        [1650,    0],
#        [1700,    0],
#        [1750,    0],
#        [1800,    0],
#        [1850,    0],
#        [1900,    0],
#        [1950,  -20],
#        [2000,  -20],
#        [2050,  -20],
#        [2100,  -20],
# ...
