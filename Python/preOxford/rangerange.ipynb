# %%
def fib(n):
      
        if n == 0:
            return 1
        elif n == 1:
            return 1
        else:
            print fib(n)/fib(n-1)
            return fib(n-1)+fib(n-2)
for i in range(0,10):
    print fib(i)
# Out:
# 1
# 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-59-ca6bde9f3952> in <module>()
#       9             return fib(n-1)+fib(n-2)
#      10 for i in range(0,10):
# ---> 11     print fib(i)
#
# <ipython-input-59-ca6bde9f3952> in fib(n)
#       6             return 1
#       7         else:
# ----> 8             print fib(n)/fib(n-1)
#       9             return fib(n-1)+fib(n-2)
#      10 for i in range(0,10):
#
# <ipython-input-59-ca6bde9f3952> in fib(n)
#       6             return 1
#       7         else:
# ----> 8             print fib(n)/fib(n-1)
#       9             return fib(n-1)+fib(n-2)
#      10 for i in range(0,10):
#
# <ipython-input-59-ca6bde9f3952> in fib(n)
#       6             return 1
#       7         else:
# ----> 8             print fib(n)/fib(n-1)
#       9             return fib(n-1)+fib(n-2)
#      10 for i in range(0,10):
#
# ...

# %%
x = [1,2,4,8]
x.append(16)
x.insert(3, 99)
x.remove(8)
x.insert(100, 1)
for i in x:
    print i
# Out:
# 1
# 2
# 4
# 99
# 16
# 1
