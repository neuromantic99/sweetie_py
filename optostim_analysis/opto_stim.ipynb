# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import utils.data_import as di
from utils.opto_stim_import import merge_sessions
from utils.opto_stim_import import opto_stim_import
import csv

# %%
LUT_path = os.path.expanduser(r'~\Documents\data\JR\behavioural_LUT.csv')
behaviour_path = os.path.expanduser(r"~\Documents\data\JR")
ID = 'J011'
task_str = 'J011-2018-11-20-133003'
date = '2018-11-20'

ms = merge_sessions(ID, behaviour_path, LUT_path)
#opto_stim_import(ID, behaviour_path, date, task_str)
# Out:
# Importing data file: J011-2018-11-20-133003.txt
# ...

# %%
223

# %%
133 + 90
# Out:
# 223
